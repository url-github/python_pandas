# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('/content/WA_Sales_Products_2012-14.csv')
products.head()
# Out:
#   Retailer country Order method type  ... Quantity Gross margin
# 0    United States               Fax  ...    489.0     0.347548
# 1    United States               Fax  ...    252.0     0.474274
# 2    United States               Fax  ...    147.0     0.352772
# 3    United States               Fax  ...    303.0     0.282938
# 4    United States               Fax  ...   1415.0     0.291450
#
# [5 rows x 11 columns]

# %%
groups = products.groupby(by='Retailer country')
groups

# %%
for country in groups:
  print(country[0])
# Out:
# Australia
# Austria
# Belgium
# Brazil
# Canada
# China
# Denmark
# Finland
# France
# Germany
# Italy
# Japan
# Korea
# Mexico
# Netherlands
# Singapore
# Spain
# Sweden
# Switzerland
# United Kingdom
# United States

# %%
country_names = []
for country in groups:
  country_names.append(country[0])

country_names
# Out:
# ['Australia',
#  'Austria',
#  'Belgium',
#  'Brazil',
#  'Canada',
#  'China',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Italy',
#  'Japan',
#  'Korea',
#  'Mexico',
#  'Netherlands',
#  'Singapore',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'United Kingdom',
#  'United States']

# %%
for country in groups:
  print(country[1])
# Out:
#       Retailer country Order method type  ... Quantity Gross margin
# 3735         Australia         Telephone  ...     53.0     0.509564
# 3736         Australia         Telephone  ...     70.0     0.507874
# 3737         Australia         Telephone  ...    158.0     0.284152
# 3738         Australia         Telephone  ...    255.0     0.413692
# 3739         Australia         Telephone  ...     46.0     0.437513
# ...                ...               ...  ...      ...          ...
# 46217        Australia       Sales visit  ...    127.0     0.299114
# 46218        Australia       Sales visit  ...    229.0     0.308627
# 46219        Australia       Sales visit  ...     97.0     0.321989
# 46220        Australia       Sales visit  ...    600.0     0.252632
# 46221        Australia       Sales visit  ...    398.0     0.291174
#
# [2086 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 7588           Austria         Telephone  ...    137.0     0.373695
# 7589           Austria         Telephone  ...     75.0     0.573601
# 7590           Austria         Telephone  ...     34.0     0.524498
# 7591           Austria         Telephone  ...     11.0     0.569964
# 7592           Austria         Telephone  ...    138.0     0.280691
# ...                ...               ...  ...      ...          ...
# 41833          Austria       Sales visit  ...     96.0     0.513012
# 41834          Austria       Sales visit  ...     96.0          NaN
# 41835          Austria       Sales visit  ...     40.0          NaN
# 41836          Austria       Sales visit  ...     40.0          NaN
# 41837          Austria       Sales visit  ...     40.0     0.636571
#
# [1805 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 7270           Belgium               Web  ...     57.0     0.509564
# 7271           Belgium               Web  ...     68.0     0.496579
# 7272           Belgium               Web  ...     96.0     0.458979
# 7273           Belgium               Web  ...     87.0     0.448898
# 7274           Belgium               Web  ...     44.0     0.571075
# ...                ...               ...  ...      ...          ...
# 41464          Belgium       Sales visit  ...     24.0     0.577135
# 41465          Belgium       Sales visit  ...    394.0     0.296456
# 41466          Belgium       Sales visit  ...     93.0     0.363657
# 41467          Belgium       Sales visit  ...     70.0     0.483432
# 41468          Belgium       Sales visit  ...     29.0          NaN
#
# [1719 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 1833            Brazil               Web  ...    219.0     0.419206
# 1834            Brazil               Web  ...     43.0     0.478828
# 1835            Brazil               Web  ...    198.0     0.388419
# 1836            Brazil               Web  ...     93.0     0.458950
# 1837            Brazil               Web  ...     60.0     0.444223
# ...                ...               ...  ...      ...          ...
# 44426           Brazil               Web  ...    167.0     0.511327
# 44427           Brazil               Web  ...    654.0     0.731544
# 44428           Brazil               Web  ...    614.0     0.521912
# 44429           Brazil               Web  ...     63.0     0.617452
# 44430           Brazil               Web  ...   1017.0     0.759189
#
# [1843 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 864             Canada               Fax  ...    165.0     0.418630
# 865             Canada               Fax  ...    114.0     0.450544
# 866             Canada               Fax  ...     17.0     0.473455
# 867             Canada               Fax  ...    271.0     0.455317
# 868             Canada               Fax  ...    621.0     0.340707
# ...                ...               ...  ...      ...          ...
# 43764           Canada       Sales visit  ...    144.0          NaN
# 43765           Canada       Sales visit  ...    634.0     0.630000
# 43766           Canada       Sales visit  ...    467.0     0.540000
# 43767           Canada       Sales visit  ...     75.0     0.598857
# 43768           Canada       Sales visit  ...     39.0     0.528333
#
# [3492 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 3403             China               Fax  ...    214.0     0.315153
# 3404             China               Fax  ...    115.0     0.445356
# 3405             China               Fax  ...    290.0     0.501355
# 3406             China               Fax  ...    214.0     0.535775
# 3407             China               Fax  ...   1568.0     0.506984
# ...                ...               ...  ...      ...          ...
# 45872            China       Sales visit  ...   1511.0     0.298984
# 45873            China       Sales visit  ...   1176.0     0.383468
# 45874            China       Sales visit  ...    902.0     0.565379
# 45875            China       Sales visit  ...   1994.0     0.520974
# 45876            China       Sales visit  ...    619.0     0.251382
#
# [2112 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 4695           Denmark               Web  ...     34.0     0.418630
# 4696           Denmark               Web  ...     19.0     0.474727
# 4697           Denmark               Web  ...     29.0     0.471715
# 4698           Denmark               Web  ...     92.0     0.391537
# 4699           Denmark               Web  ...     81.0     0.445985
# ...                ...               ...  ...      ...          ...
# 47129          Denmark               Web  ...   1398.0     0.326553
# 47130          Denmark               Web  ...    509.0     0.422953
# 47131          Denmark               Web  ...    737.0     0.450244
# 47132          Denmark               Web  ...     68.0     0.533672
# 47133          Denmark               Web  ...     39.0     0.341240
#
# [1392 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 4913           Finland               Web  ...   2586.0     0.526656
# 4914           Finland               Web  ...   1205.0     0.496009
# 4915           Finland               Web  ...    880.0     0.310091
# 4916           Finland               Web  ...    794.0     0.336810
# 4917           Finland               Web  ...   9282.0     0.496847
# ...                ...               ...  ...      ...          ...
# 47454          Finland               Web  ...    981.0     0.339232
# 47455          Finland               Web  ...   3724.0     0.728682
# 47456          Finland               Web  ...   3927.0     0.517297
# 47457          Finland               Web  ...    365.0     0.617452
# 47458          Finland               Web  ...   2637.0     0.757143
#
# [1923 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 5205            France               Fax  ...     39.0     0.445356
# 5206            France               Fax  ...     47.0     0.449550
# 5207            France               Fax  ...    135.0     0.459332
# 5208            France               Fax  ...   8136.0     0.465823
# 5209            France               Fax  ...   1081.0     0.496009
# ...                ...               ...  ...      ...          ...
# 47844           France               Web  ...    663.0     0.565379
# 47845           France               Web  ...    211.0     0.504016
# 47846           France               Web  ...    668.0     0.342635
# 47847           France               Web  ...    822.0     0.281019
# 47848           France               Web  ...      NaN          NaN
#
# [3389 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 5807           Germany              Mail  ...    402.0     0.336810
# 5808           Germany              Mail  ...    235.0     0.347548
# 5809           Germany              Mail  ...    458.0     0.460043
# 5810           Germany              Mail  ...    520.0     0.281444
# 5811           Germany              Mail  ...    158.0     0.282938
# ...                ...               ...  ...      ...          ...
# 40195          Germany               Web  ...     95.0          NaN
# 40196          Germany               Web  ...   1099.0     0.710803
# 40197          Germany               Web  ...    597.0     0.439257
# 40198          Germany               Web  ...    130.0     0.630606
# 40199          Germany               Web  ...    462.0     0.761905
#
# [2466 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 7934             Italy               Fax  ...    126.0     0.329056
# 7935             Italy               Fax  ...     75.0     0.291657
# 7936             Italy               Fax  ...    113.0     0.301264
# 7937             Italy               Fax  ...    190.0     0.427688
# 7938             Italy               Fax  ...    265.0     0.564981
# ...                ...               ...  ...      ...          ...
# 42223            Italy               Web  ...     99.0     0.483364
# 42224            Italy               Web  ...     61.0     0.527765
# 42225            Italy               Web  ...    172.0     0.511327
# 42226            Italy               Web  ...    150.0     0.465035
# 42227            Italy               Web  ...   1396.0     0.728682
#
# [1889 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 2146             Japan               Fax  ...   7091.0     0.465823
# 2147             Japan               Fax  ...    957.0     0.466974
# 2148             Japan               Fax  ...    151.0     0.434205
# 2149             Japan               Fax  ...    462.0     0.467061
# 2150             Japan               Fax  ...    129.0     0.329056
# ...                ...               ...  ...      ...          ...
# 44891            Japan       Sales visit  ...    217.0     0.407454
# 44892            Japan       Sales visit  ...    108.0     0.457647
# 44893            Japan       Sales visit  ...    303.0     0.337722
# 44894            Japan       Sales visit  ...    436.0     0.642000
# 44895            Japan       Sales visit  ...     53.0     0.632887
#
# [3048 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 3074             Korea         Telephone  ...   1030.0     0.449709
# 3075             Korea         Telephone  ...    565.0     0.347548
# 3076             Korea         Telephone  ...    839.0     0.260994
# 3077             Korea         Telephone  ...    769.0     0.291450
# 3078             Korea         Telephone  ...    381.0     0.388535
# ...                ...               ...  ...      ...          ...
# 45529            Korea               Web  ...    164.0     0.465035
# 45530            Korea               Web  ...    755.0     0.731544
# 45531            Korea               Web  ...   1955.0     0.519298
# 45532            Korea               Web  ...    104.0     0.617452
# 45533            Korea               Web  ...   1616.0     0.757143
#
# [1920 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 1468            Mexico               Web  ...     21.0     0.474727
# 1469            Mexico               Web  ...     34.0     0.478828
# 1470            Mexico               Web  ...     26.0     0.451702
# 1471            Mexico               Web  ...     17.0     0.444782
# 1472            Mexico               Web  ...    126.0     0.340209
# ...                ...               ...  ...      ...          ...
# 44119           Mexico       Sales visit  ...    162.0     0.421524
# 44120           Mexico       Sales visit  ...    279.0     0.337722
# 44121           Mexico       Sales visit  ...    118.0     0.483432
# 44122           Mexico       Sales visit  ...    688.0     0.690000
# 44123           Mexico       Sales visit  ...    173.0     0.731429
#
# [2202 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 4072       Netherlands               Fax  ...   1187.0     0.760563
# 4073       Netherlands               Fax  ...    297.0     0.347548
# 4074       Netherlands               Fax  ...    556.0     0.260994
# 4075       Netherlands               Fax  ...    348.0     0.474274
# 4076       Netherlands               Fax  ...   1630.0     0.494949
# ...                ...               ...  ...      ...          ...
# 46610      Netherlands       Sales visit  ...    202.0     0.331549
# 46611      Netherlands       Sales visit  ...    452.0     0.690000
# 46612      Netherlands       Sales visit  ...   1024.0     0.647230
# 46613      Netherlands       Sales visit  ...    245.0     0.610000
# 46614      Netherlands       Sales visit  ...     78.0     0.608696
#
# [2440 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 2750         Singapore               Fax  ...    944.0     0.336810
# 2751         Singapore               Fax  ...    378.0     0.529480
# 2752         Singapore               Fax  ...    429.0     0.273356
# 2753         Singapore               Fax  ...    250.0     0.316417
# 2754         Singapore               Fax  ...    103.0     0.361866
# ...                ...               ...  ...      ...          ...
# 45206        Singapore           Special  ...    762.0     0.299203
# 45207        Singapore           Special  ...    318.0     0.296456
# 45208        Singapore           Special  ...    338.0     0.407454
# 45209        Singapore           Special  ...    173.0     0.463960
# 45210        Singapore           Special  ...    151.0     0.421524
#
# [1972 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 8310             Spain               Fax  ...   1926.0     0.537125
# 8311             Spain               Fax  ...    834.0     0.763231
# 8312             Spain               Fax  ...    231.0     0.376902
# 8313             Spain               Fax  ...     51.0     0.373695
# 8314             Spain               Fax  ...     22.0     0.577135
# ...                ...               ...  ...      ...          ...
# 42569            Spain               Web  ...    229.0     0.465035
# 42570            Spain               Web  ...   1289.0     0.667558
# 42571            Spain               Web  ...   2220.0     0.462157
# 42572            Spain               Web  ...    421.0     0.628455
# 42573            Spain               Web  ...   1557.0     0.757143
#
# [1635 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 4453            Sweden            E-mail  ...    965.0     0.601404
# 4454            Sweden            E-mail  ...    150.0     0.282938
# 4455            Sweden            E-mail  ...    344.0     0.291450
# 4456            Sweden            E-mail  ...    144.0     0.398146
# 4457            Sweden            E-mail  ...    151.0     0.335607
# ...                ...               ...  ...      ...          ...
# 46895           Sweden       Sales visit  ...     44.0     0.451186
# 46896           Sweden       Sales visit  ...     43.0     0.527765
# 46897           Sweden       Sales visit  ...    113.0     0.511327
# 46898           Sweden       Sales visit  ...    588.0     0.731544
# 46899           Sweden       Sales visit  ...    339.0     0.761905
#
# [1567 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 6318       Switzerland               Fax  ...     25.0     0.473455
# 6319       Switzerland               Fax  ...     30.0     0.471715
# 6320       Switzerland               Fax  ...    126.0     0.391537
# 6321       Switzerland               Fax  ...     84.0     0.448412
# 6322       Switzerland               Fax  ...     20.0     0.444782
# ...                ...               ...  ...      ...          ...
# 40590      Switzerland       Sales visit  ...     96.0     0.511327
# 40591      Switzerland       Sales visit  ...     42.0          NaN
# 40592      Switzerland       Sales visit  ...     80.0          NaN
# 40593      Switzerland       Sales visit  ...     80.0          NaN
# 40594      Switzerland       Sales visit  ...    119.0     0.630519
#
# [1940 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 6696    United Kingdom               Fax  ...    570.0     0.419461
# 6697    United Kingdom               Fax  ...    170.0     0.474224
# 6698    United Kingdom               Fax  ...    124.0     0.448247
# 6699    United Kingdom               Fax  ...     51.0     0.466953
# 6700    United Kingdom               Fax  ...    132.0     0.417333
# ...                ...               ...  ...      ...          ...
# 41084   United Kingdom       Sales visit  ...     52.0     0.536324
# 41085   United Kingdom       Sales visit  ...    122.0     0.500060
# 41086   United Kingdom       Sales visit  ...    249.0     0.288314
# 41087   United Kingdom       Sales visit  ...    176.0     0.507874
# 41088   United Kingdom       Sales visit  ...    218.0     0.465035
#
# [2493 rows x 11 columns]
#       Retailer country Order method type  ... Quantity Gross margin
# 0        United States               Fax  ...    489.0     0.347548
# 1        United States               Fax  ...    252.0     0.474274
# 2        United States               Fax  ...    147.0     0.352772
# 3        United States               Fax  ...    303.0     0.282938
# 4        United States               Fax  ...   1415.0     0.291450
# ...                ...               ...  ...      ...          ...
# 43170    United States       Sales visit  ...     62.0     0.273312
# 43171    United States       Sales visit  ...    289.0     0.388753
# 43172    United States       Sales visit  ...    132.0     0.426829
# 43173    United States       Sales visit  ...     46.0     0.337722
# 43174    United States       Sales visit  ...     50.0     0.483432
#
# [4516 rows x 11 columns]

# %%
for country in groups:
  print(country[0],len(country[1]))
# Out:
# Australia 2086
# Austria 1805
# Belgium 1719
# Brazil 1843
# Canada 3492
# China 2112
# Denmark 1392
# Finland 1923
# France 3389
# Germany 2466
# Italy 1889
# Japan 3048
# Korea 1920
# Mexico 2202
# Netherlands 2440
# Singapore 1972
# Spain 1635
# Sweden 1567
# Switzerland 1940
# United Kingdom 2493
# United States 4516

# %% [markdown]
# Teraz pętla for operuje na 2 zmiennych:

# %%
for country, country_data in groups:
  print(country,len(country_data))
# Out:
# Australia 2086
# Austria 1805
# Belgium 1719
# Brazil 1843
# Canada 3492
# China 2112
# Denmark 1392
# Finland 1923
# France 3389
# Germany 2466
# Italy 1889
# Japan 3048
# Korea 1920
# Mexico 2202
# Netherlands 2440
# Singapore 1972
# Spain 1635
# Sweden 1567
# Switzerland 1940
# United Kingdom 2493
# United States 4516

# %%
for country, country_data in groups:
  print(country,
        country_data['Revenue'].max() - country_data['Revenue'].min())
# Out:
# Australia 420537.25
# Austria 202194.6
# Belgium 297823.68
# Brazil 352749.39
# Canada 557173.1
# China 741197.29
# Denmark 167214.0
# Finland 510275.61
# France 453852.63
# Germany 368497.76
# Italy 360235.26
# Japan 686566.27
# Korea 535425.66
# Mexico 459086.36
# Netherlands 506648.03
# Singapore 539257.95
# Spain 326654.98
# Sweden 289064.16
# Switzerland 212965.83
# United Kingdom 605546.68
# United States 1415141.91

# %%
for country, country_data in groups:
  print(country,
        country_data['Revenue'].max(),
        country_data['Revenue'].idxmax())
# Out:
# Australia 420537.25 45962
# Austria 202194.6 41539
# Belgium 297823.68 32833
# Brazil 352749.39 44350
# Canada 557173.1 43621
# China 741197.29 45656
# Denmark 167214.0 38787
# Finland 510275.61 47448
# France 453852.63 31155
# Germany 368497.76 39936
# Italy 360235.26 33603
# Japan 686566.27 44802
# Korea 535425.66 28879
# Mexico 459086.36 10376
# Netherlands 506648.03 46489
# Singapore 539257.95 28557
# Spain 326654.98 42489
# Sweden 289064.16 30188
# Switzerland 212965.83 32070
# United Kingdom 605546.68 15898
# United States 1415141.91 43029

# %%
for country,country_data in groups:
  print(country,
        country_data['Revenue'].max(),
        country_data['Revenue'].idxmax(),
        country_data.loc[country_data['Revenue'].idxmax()])
# Out:
# Australia 420537.25 45962 Retailer country                        Australia
# Order method type                             Web
# Retailer type                           Golf Shop
# Product line                       Golf Equipment
# Product type                                Woods
# Product              Hailstorm Titanium Woods Set
# Year                                         2013
# Quarter                                   Q2 2013
# Revenue                                    420537
# Quantity                                      357
# Gross margin                             0.498956
# Name: 45962, dtype: object
# Austria 202194.6 41539 Retailer country                   Austria
# Order method type                      Web
# Retailer type                    Golf Shop
# Product line                Golf Equipment
# Product type                         Irons
# Product              Hailstorm Steel Irons
# Year                                  2013
# Quarter                            Q1 2013
# Revenue                             202195
# Quantity                               448
# Gross margin                      0.510333
# Name: 41539, dtype: object
# Belgium 297823.68 32833 Retailer country               Belgium
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         297824
# Quantity                           544
# Gross margin                  0.282938
# Name: 32833, dtype: object
# Brazil 352749.39 44350 Retailer country                Brazil
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q2 2013
# Revenue                         352749
# Quantity                           996
# Gross margin                  0.294116
# Name: 44350, dtype: object
# Canada 557173.1 43621 Retailer country                Canada
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2013
# Quarter                        Q2 2013
# Revenue                         557173
# Quantity                          1007
# Gross margin                  0.290493
# Name: 43621, dtype: object
# China 741197.29 45656 Retailer country                 China
# Order method type                  Web
# Retailer type            Outdoors Shop
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q2 2013
# Revenue                         741197
# Quantity                          2096
# Gross margin                  0.293036
# Name: 45656, dtype: object
# Denmark 167214.0 38787 Retailer country                       Denmark
# Order method type                          Web
# Retailer type                     Sports Store
# Product line                    Golf Equipment
# Product type                             Woods
# Product              Hailstorm Steel Woods Set
# Year                                      2013
# Quarter                                Q1 2013
# Revenue                                 167214
# Quantity                                   275
# Gross margin                          0.438205
# Name: 38787, dtype: object
# Finland 510275.61 47448 Retailer country                          Finland
# Order method type                             Web
# Retailer type                        Sports Store
# Product line                       Golf Equipment
# Product type                                Woods
# Product              Hailstorm Titanium Woods Set
# Year                                         2013
# Quarter                                   Q2 2013
# Revenue                                    510276
# Quantity                                      433
# Gross margin                              0.49876
# Name: 47448, dtype: object
# France 453852.63 31155 Retailer country                France
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         453853
# Quantity                           829
# Gross margin                  0.282938
# Name: 31155, dtype: object
# Germany 368497.76 39936 Retailer country               Germany
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q1 2013
# Revenue                         368498
# Quantity                          1048
# Gross margin                  0.289005
# Name: 39936, dtype: object
# Italy 360235.26 33603 Retailer country                 Italy
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         360235
# Quantity                           658
# Gross margin                  0.282938
# Name: 33603, dtype: object
# Japan 686566.27 44802 Retailer country                 Japan
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q2 2013
# Revenue                         686566
# Quantity                          1946
# Gross margin                  0.291401
# Name: 44802, dtype: object
# Korea 535425.66 28879 Retailer country                 Korea
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         535426
# Quantity                           978
# Gross margin                  0.282938
# Name: 28879, dtype: object
# Mexico 459086.36 10376 Retailer country                Mexico
# Order method type          Sales visit
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2012
# Quarter                        Q2 2012
# Revenue                         459086
# Quantity                          1259
# Gross margin                  0.314399
# Name: 10376, dtype: object
# Netherlands 506648.03 46489 Retailer country           Netherlands
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q2 2013
# Revenue                         506648
# Quantity                          1432
# Gross margin                  0.293395
# Name: 46489, dtype: object
# Singapore 539257.95 28557 Retailer country             Singapore
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         539258
# Quantity                           985
# Gross margin                  0.282938
# Name: 28557, dtype: object
# Spain 326654.98 42489 Retailer country                 Spain
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q1 2013
# Revenue                         326655
# Quantity                           929
# Gross margin                  0.289005
# Name: 42489, dtype: object
# Sweden 289064.16 30188 Retailer country                Sweden
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         289064
# Quantity                           528
# Gross margin                  0.282938
# Name: 30188, dtype: object
# Switzerland 212965.83 32070 Retailer country           Switzerland
# Order method type                  Web
# Retailer type          Warehouse Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                   Star Gazer 2
# Year                              2012
# Quarter                        Q4 2012
# Revenue                         212966
# Quantity                           389
# Gross margin                  0.282938
# Name: 32070, dtype: object
# United Kingdom 605546.68 15898 Retailer country        United Kingdom
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2012
# Quarter                        Q2 2012
# Revenue                         605547
# Quantity                          1658
# Gross margin                  0.315495
# Name: 15898, dtype: object
# United States 1415141.91 43029 Retailer country         United States
# Order method type                  Web
# Retailer type             Sports Store
# Product line         Camping Equipment
# Product type                     Tents
# Product                      Star Lite
# Year                              2013
# Quarter                        Q2 2013
# Revenue                    1.41514e+06
# Quantity                          4011
# Gross margin                  0.291414
# Name: 43029, dtype: object

# %%
the_biggest = pd.DataFrame()
for country, country_data in groups:
  the_biggest = the_biggest.append(country_data.loc[country_data['Revenue'].idxmax()])

# %%
the_biggest.head()
# Out:
#        Gross margin Order method type  ...    Revenue    Year
# 45962      0.498956               Web  ...  420537.25  2013.0
# 41539      0.510333               Web  ...  202194.60  2013.0
# 32833      0.282938               Web  ...  297823.68  2012.0
# 44350      0.294116               Web  ...  352749.39  2013.0
# 43621      0.290493               Web  ...  557173.10  2013.0
#
# [5 rows x 11 columns]

# %%
the_biggest = pd.DataFrame()
for country, country_data in groups:
  the_biggest = the_biggest.append(country_data.nlargest(1,'Revenue'))

# %%
the_biggest.head()
# Out:
#       Retailer country Order method type  ... Quantity Gross margin
# 45962        Australia               Web  ...    357.0     0.498956
# 41539          Austria               Web  ...    448.0     0.510333
# 32833          Belgium               Web  ...    544.0     0.282938
# 44350           Brazil               Web  ...    996.0     0.294116
# 43621           Canada               Web  ...   1007.0     0.290493
#
# [5 rows x 11 columns]
